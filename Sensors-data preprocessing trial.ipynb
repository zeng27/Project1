# %%
#import json
import pandas as pd
import numpy as np
import sys
reload(sys)
sys.setdefaultencoding('utf-8')

# %%
file_data = 'C:/Users/Yan/Git/Track2/sensorswww_data.txt'

# %%
# checks 
#pd.__version__
#import platform
#platform.python_version()
#sys.version

# %%
dat = pd.read_table(file_data, encoding='utf-8', header=None)

# %%
dat.head()
# Out:
#                                                    0
# 0  {"distinct_id":"595466e9a8e733434ce08de16e927d...
# 1  {"distinct_id":"9939d3e087bca29c42334d96dccd25...
# 2  {"distinct_id":"9939d3e087bca29c42334d96dccd25...
# 3  {"distinct_id":"9939d3e087bca29c42334d96dccd25...
# 4  {"distinct_id":"9939d3e087bca29c42334d96dccd25...

# %%
#extract list
#feature list
#for extract_i in extract_list:
#    feature_i = dat[0].str.extract(extract_i)
#    fearure_i = feature_i.str.replace()
#    dat['feature_i']=feature_i


user_id_extract = '(distinct_id":"\w{40})'
user_id = dat[0].str.extract(user_id_extract)
user_id = user_id.str.replace('distinct_id\"\:\"','')
dat['user_id']=user_id

event_extract = '(index_leave|btnClick|)'
event = dat[0].str.extract(event_extract)
event = event.str.replace('event\"\:\"','') 
event[::-1] = event.str.replace('\"','')[::-1]
dat['event']=event

time = dat[0].str.extract('(time":\d{13})')
time = time.str.replace('time\"\:','')
dat['time']=time

latest_referrer_extract = '(latest_referrer":"\w{1,5}\:\//.{1,14}\:.{1,14}\/.{1,14}\/?.{1,14}?\/?.{1,14}?\,|latest_referrer":"\w{1,5}\:\//.{1,14}\..{1,14}?\/?.{1,100}?\,|latest_referrer":"\w{1,5}\:\//.{1,14}\..{1,14}\.?.{1,14}?\/.{1,14}?\.?.{1,14}?\,|latest_referrer":"\w{1,5}\:\//.{1,14}\..{1,14}\.?.{1,14}?\/.{1,100}\.?.{1,100}?\,|latest_referrer":"\w{1,5}\:\//.{1,14}\..{1,14}\..{1,14}\..{1,14}\:.{1,14}\/.{1,14}\/?.{1,14}?\,|latest_referrer":"\w{1,5}\:\//.{1,14}\..{1,14}\..{1,14}\..{1,14}\:.{1,14}\/.{1,14}\/?.{1,14}?\/?.{1,14}?\,)'     
latest_referrer = dat[0].str.extract(latest_referrer_extract)
latest_referrer = latest_referrer.str.replace('latest_referrer\"\:\"','')
latest_referrer[::-1] = latest_referrer.str.replace('\"\,','')[::-1]
dat['latest_referrer']=latest_referrer

latest_referrer_host_extract = '(latest_referrer_host":".{1,14}\..{1,14}\.?.{1,14}?\,)'
latest_referrer_host = dat[0].str.extract(latest_referrer_host_extract)
latest_referrer_host = latest_referrer_host.str.replace('latest_referrer_host\"\:\"','')
latest_referrer_host[::-1] = latest_referrer_host.str.replace('\"\,','')[::-1]
dat['latest_referrer_host']=latest_referrer_host

latest_utm_source_extract = '(latest_utm_source":"\w{1,20}\.\w{1,20}\.?\w{1,20}|latest_utm_source":"\w{1,20})'
latest_utm_source = dat[0].str.extract(latest_utm_source_extract)
latest_utm_source = latest_utm_source.str.replace('latest_utm_source\"\:\"','')
dat['latest_utm_source']=latest_utm_source



latest_ch_extract = '(latest_ch":".{1,20}\"\,)'
latest_ch = dat[0].str.extract(latest_ch_extract)
latest_ch = latest_ch.str.replace('latest_ch\"\:\"','')
latest_ch [::-1] = latest_ch .str.replace('\"\,','')[::-1]
dat['latest_ch']=latest_ch


session_referrer_host_extract = '(session_referrer_host":"www.baidu.com|session_referrer_host":"mail.alibaba-inc.com)'
session_referrer_host = dat[0].str.extract(session_referrer_host_extract)
session_referrer_host = session_referrer_host.str.replace('session_referrer_host\"\:\"','')
dat['session_referrer_host']=session_referrer_host

pageStayTime_extract = '(pageStayTime":\d{0,7}.\d{0,3})'
pageStayTime = dat[0].str.extract(pageStayTime_extract)
pageStayTime = pageStayTime.str.replace('pageStayTime\"\:','')
dat['pageStayTime']=pageStayTime


session_referrer_extract = '(session_referrer":"\w{1,5}\:\//.{1,14}\:.{1,14}\/.{1,14}\/?.{1,14}?\/?.{1,14}?\,|session_referrer":"\w{1,5}\:\//.{1,14}\..{1,14}?\/?.{1,100}?\,|session_referrer":"\w{1,5}\:\//.{1,14}\..{1,14}\.?.{1,14}?\/.{1,14}?\.?.{1,14}?\,|session_referrer":"\w{1,5}\:\//.{1,14}\..{1,14}\.?.{1,14}?\/.{1,100}\.?.{1,100}?\,|session_referrer":"\w{1,5}\:\//.{1,14}\..{1,14}\..{1,14}\..{1,14}\:.{1,14}\/.{1,14}\/?.{1,14}?\,|session_referrer":"\w{1,5}\:\//.{1,14}\..{1,14}\..{1,14}\..{1,14}\:.{1,14}\/.{1,14}\/?.{1,14}?\/?.{1,14}?\,)'     
session_referrer = dat[0].str.extract(session_referrer_extract)
session_referrer = session_referrer.str.replace('session_referrer\"\:\"','')
session_referrer[::-1] = session_referrer.str.replace('\"\,','')[::-1]
dat['session_referrer']=session_referrer

session_referrer_host_extract = '(session_referrer_host":".{1,14}\..{1,14}\.?.{1,14}?\,)'
session_referrer_host = dat[0].str.extract(session_referrer_host_extract)
session_referrer_host = session_referrer_host.str.replace('session_referrer_host\"\:\"','')
session_referrer_host[::-1] = session_referrer_host.str.replace('\"\,','')[::-1]
dat['session_referrer_host']=session_referrer_host

# %%
event_extract = '(page_close|index_leave|btnClick|about_leave|formSubmit|clickSubmit|courses_leave|demo_leave|courses_play_leave|pageview|click_send_cellphone|verify_cellphone_code)'
event = dat[0].str.extract(event_extract)
event = event.str.replace('event\"\:\"','') 
event[::-1] = event.str.replace('\"','')[::-1]
dat['event']=event

# %%
dat.head()
# Out:
#                                                    0  \
# 0  {"distinct_id":"595466e9a8e733434ce08de16e927d...
# 1  {"distinct_id":"9939d3e087bca29c42334d96dccd25...
# 2  {"distinct_id":"9939d3e087bca29c42334d96dccd25...
# 3  {"distinct_id":"9939d3e087bca29c42334d96dccd25...
# 4  {"distinct_id":"9939d3e087bca29c42334d96dccd25...
#
#                                     user_id        event           time  \
# 0  595466e9a8e733434ce08de16e927d985e0b5d48  index_leave  1488791047953
# 1  9939d3e087bca29c42334d96dccd25ca0e06652a          NaN  1490958296645
# 2  9939d3e087bca29c42334d96dccd25ca0e06652a     pageview  1488791050856
# 3  9939d3e087bca29c42334d96dccd25ca0e06652a     btnClick  1488791051772
# 4  9939d3e087bca29c42334d96dccd25ca0e06652a     btnClick  1488791056032
#
#   latest_referrer latest_referrer_host latest_utm_source latest_ch  \
# 0             NaN                  NaN             baidu      demo
# 1             NaN                  NaN               NaN       NaN
# ...

# %%
## back up 

is_first_day_extract = '(is_first_day":\w{4,5})'
is_first_day = dat[0].str.extract(is_first_day_extract)
is_first_day = is_first_day.str.replace('is_first_day\"\:','')
dat['is_first_day']=is_first_day

is_first_time_extract = '(is_first_time":\w{4,5})'
is_first_time = dat[0].str.extract(is_first_time_extract)
is_first_time = is_first_time.str.replace('is_first_time\"\:','')
dat['is_first_time']=is_first_time

latest_utm_medium_extract = '(latest_utm_medium":"\w{1,20}\.\w{1,20}\.?\w{1,20}|latest_utm_medium":"\w{1,20})'
latest_utm_medium= dat[0].str.extract(latest_utm_medium_extract)
latest_utm_medium = latest_utm_medium.str.replace('latest_utm_medium\"\:\"','')
dat['latest_utm_medium']=latest_utm_medium



os_extract = '(os":"\w{3,7})'
os = dat[0].str.extract(os_extract)
os = os.str.replace('os\"\:\"','')
dat['os']=os

os_version_extract = '(os_version":"\w\w?.\w\w?|os_version":"-\d)'
os_version = dat[0].str.extract(os_version_extract)
os_version = os_version.str.replace('os_version\"\:\"','')
dat['os_version']=os_version

model_extract = '(model":"\w{2,7})'
model = dat[0].str.extract(model_extract)
model = model.str.replace('model\"\:\"','')
dat['model']=model

screen_height_extract = '(screen_height":\d{3,4})'
screen_height = dat[0].str.extract(screen_height_extract)
screen_height = screen_height.str.replace('screen_height\"\:','')
dat['screen_height']=screen_height

screen_width_extract = '(screen_width":\d{3,4})'
screen_width = dat[0].str.extract(screen_width_extract)
screen_width = screen_width.str.replace('screen_width\"\:','')
dat['screen_width']=screen_width

browser_extract = '(browser":"\w{3}-\w{2}|browser":"\w{2,14})' 
browser = dat[0].str.extract(browser_extract)
browser = browser.str.replace('browser\"\:\"','')
dat['browser']=browser

browser_version_extract = '(browser_version":"-\d|browser_version":"\d?\d?\.?\d?\d?\d?\d?\d?)'
browser_version = dat[0].str.extract(browser_version_extract)
browser_version = browser_version.str.replace('browser_version\"\:\"','')
dat['browser_version']=browser_version

latest_utm_campaign_extract = '(latest_utm_campaign":".{1,50}?\"\,|latest_utm_campaign":".{1,50}\-.{1,50}\"\,)'
latest_utm_campaign= dat[0].str.extract(latest_utm_campaign_extract)
latest_utm_campaign = latest_utm_campaign.str.replace('latest_utm_campaign\"\:\"','')
latest_utm_campaign[::-1] = latest_utm_campaign.str.replace('\"\,','')[::-1]
dat['latest_utm_campaign']=latest_utm_campaign

latest_utm_content_extract = '(latest_utm_content":".{1,120}?\"\,|latest_utm_content":".{1,50}\-.{1,50}\"\,)'
latest_utm_content= dat[0].str.extract(latest_utm_content_extract)
latest_utm_content = latest_utm_content.str.replace('latest_utm_content\"\:\"','')
latest_utm_content[::-1] = latest_utm_content.str.replace('\"\,','')[::-1]
dat['latest_utm_content']=latest_utm_content

latest_utm_term_extract = '(latest_utm_term":".{1,120}?\"\,|latest_utm_term":".{1,50}\-.{1,50}\"\,)'
latest_utm_term= dat[0].str.extract(latest_utm_term_extract)
latest_utm_term = latest_utm_term.str.replace('latest_utm_term\"\:\"','')
latest_utm_term[::-1] = latest_utm_term.str.replace('\"\,','')[::-1]
dat['latest_utm_term']=latest_utm_term

session_page_url_extract = '(session_page_url":"\w{1,4}\:\///\w\:\/.{1,14}\/.{1,14}\/.{1,14}\/.{1,250}?\,|session_page_url":"\w{1,5}\:\//.{1,14}\:.{1,14}\/?\,|session_page_url":"\w{1,5}\:\//.{1,14}\:.{1,14}\/.{1,14}?\/?.{1,14}?\/?.{1,14}?\,|session_page_url":"\w{1,5}\:\//.{1,14}\..{1,14}?\/?.{1,100}?\,|session_page_url":"\w{1,5}\:\//.{1,14}\..{1,14}\.?.{1,250}?\/.{1,250}?\.?.{1,250}?\,|session_page_url":"\w{1,5}\:\//.{1,14}\..{1,14}\.?.{1,14}?\/.{1,100}\.?.{1,100}?\,|session_page_url":"\w{1,5}\:\//.{1,14}\..{1,14}\..{1,14}\..{1,14}\:.{1,14}\/.{1,14}\/?.{1,14}?\,|session_page_url":"\w{1,5}\:\//.{1,14}\..{1,14}\..{1,14}\..{1,14}\:.{1,14}\/.{1,14}\/?.{1,14}?\/?.{1,14}?\,)'     
session_page_url = dat[0].str.extract(session_page_url_extract)
session_page_url = session_page_url.str.replace('session_page_url\"\:\"','')
session_page_url[::-1] = session_page_url.str.replace('\"\,','')[::-1]
dat['session_page_url']=session_page_url

pageUrl_extract = '(pageUrl":"\w{1,4}\:\///\w\:\/.{1,14}\/.{1,14}\/.{1,14}\/.{1,250}?\,|pageUrl":"\w{1,5}\:\//.{1,14}\:.{1,14}\/?\,|pageUrl":"\w{1,5}\:\//.{1,14}\:.{1,14}\/.{1,14}?\/?.{1,14}?\/?.{1,14}?\,|pageUrl":"\w{1,5}\:\//.{1,14}\..{1,14}?\/?.{1,100}?\,|pageUrl":"\w{1,5}\:\//.{1,14}\..{1,14}\.?.{1,250}?\/.{1,250}?\.?.{1,250}?\,|pageUrl":"\w{1,5}\:\//.{1,14}\..{1,14}\.?.{1,14}?\/.{1,100}\.?.{1,100}?\,|pageUrl":"\w{1,5}\:\//.{1,14}\..{1,14}\..{1,14}\..{1,14}\:.{1,14}\/.{1,14}\/?.{1,14}?\,|pageUrl":"\w{1,5}\:\//.{1,14}\..{1,14}\..{1,14}\..{1,14}\:.{1,14}\/.{1,14}\/?.{1,14}?\/?.{1,14}?\,)'     
pageUrl = dat[0].str.extract(pageUrl_extract)
pageUrl = pageUrl.str.replace('pageUrl\"\:\"','')
pageUrl[::-1] = pageUrl.str.replace('\"\,','')[::-1]
dat['pageUrl']=pageUrl

ip_extract = '(ip":"\w{0,3}\.\w{0,3}\.\w{0,3}\.\w{0,3}\")'
ip = dat[0].str.extract(ip_extract)
ip = ip.str.replace('ip\"\:\"','') 
ip[::-1] = ip.str.replace('\"','')[::-1]
dat['ip']=ip

types_extract = '(type":"\w{1,20})'
types = dat[0].str.extract(types_extract)
types = types.str.replace('type\"\:\"','') 
types[::-1] = types.str.replace('\"','')[::-1]
dat['types']=types

nocache_extract = '(nocache":"\w{1,20})'
nocache = dat[0].str.extract(nocache_extract)
nocache = nocache.str.replace('nocache\"\:\"','') 
nocache[::-1] = nocache.str.replace('\"','')[::-1]
dat['nocache']=nocache

page_extract = '(page":"\w{1,20}\")'
page = dat[0].str.extract(page_extract)
page = page.str.replace('page\"\:\"','') 
page[::-1] = page.str.replace('\"','')[::-1]
dat['page']=page

name_extract = '(name":".{1,20}\"\,)'
name = dat[0].str.extract(name_extract)
name = name.str.replace('name\"\:\"','') 
name[::-1] = name.str.replace('\"\,','')[::-1]
dat['name']=name

requestBtn_extract = '(requestBtn":"\d{0,3}\"\,)'
requestBtn = dat[0].str.extract(requestBtn_extract)
requestBtn = requestBtn.str.replace('requestBtn\"\:\"','') 
requestBtn[::-1] = requestBtn.str.replace('\"\,','')[::-1]
dat['requestBtn']=requestBtn

pagePosition_extract = '(pagePosition":\d{1,3}\,)'
pagePosition = dat[0].str.extract(pagePosition_extract)
pagePosition = pagePosition.str.replace('pagePosition\"\:','') 
pagePosition[::-1] = pagePosition.str.replace('\,','')[::-1]
dat['pagePosition']=pagePosition

isSuccess_extract = '(isSuccess":\w{4,5}\,)'
isSuccess = dat[0].str.extract(isSuccess_extract)
isSuccess = isSuccess.str.replace('isSuccess\"\:','') 
isSuccess[::-1] = isSuccess.str.replace('\,','')[::-1]
dat['isSuccess']=isSuccess

isMsg_extract = '(isMsg":\w{4,5})'
isMsg = dat[0].str.extract(isMsg_extract)
isMsg = isMsg.str.replace('isMsg\"\:','') 
dat['isMsg']=isMsg

verification_code_extract = '(verification_code":"\w{2,15}\"\,)'
verification_code = dat[0].str.extract(verification_code_extract)
verification_code = verification_code.str.replace('verification_code\"\:\"','') 
verification_code[::-1] = verification_code.str.replace('\"\,','')[::-1]
dat['verification_code']=verification_code

contact_extract = '(contact":".{1,20}\"\,)'
contact = dat[0].str.extract(contact_extract)
contact = contact.str.replace('contact\"\:\"','') 
contact[::-1] = contact.str.replace('\"\,','')[::-1]
dat['contact']=contact

company_extract = '(company":".{1,20}\"\,)'
company = dat[0].str.extract(company_extract)
company = company.str.replace('company\"\:\"','') 
company[::-1] = company.str.replace('\"\,','')[::-1]
dat['company']=company

email_extract = '(email":".{1,50}\"\,)'
email = dat[0].str.extract(email_extract)
email = email.str.replace('email\"\:\"','') 
email[::-1] = email.str.replace('\"\,','')[::-1]
dat['email']=email

site_url_extract = '(site_url":"\w{1,4}\:\///\w\:\/.{1,14}\/.{1,14}\/.{1,14}\/.{1,250}?\,|site_url":"\w{1,5}\:\//.{1,14}\:.{1,14}\/?\,|site_url":"\w{1,5}\:\//.{1,14}\:.{1,14}\/.{1,14}?\/?.{1,14}?\/?.{1,14}?\,|site_url":"\w{1,5}\:\//.{1,14}\..{1,14}?\/?.{1,100}?\,|site_url":"\w{1,5}\:\//.{1,14}\..{1,14}\.?.{1,250}?\/.{1,250}?\.?.{1,250}?\,|site_url":"\w{1,5}\:\//.{1,14}\..{1,14}\.?.{1,14}?\/.{1,100}\.?.{1,100}?\,|site_url":"\w{1,5}\:\//.{1,14}\..{1,14}\..{1,14}\..{1,14}\:.{1,14}\/.{1,14}\/?.{1,14}?\,|site_url":"\w{1,5}\:\//.{1,14}\..{1,14}\..{1,14}\..{1,14}\:.{1,14}\/.{1,14}\/?.{1,14}?\/?.{1,14}?\,)'     
site_url = dat[0].str.extract(site_url_extract)
site_url = site_url.str.replace('site_url\"\:\"','')
site_url[::-1] = site_url.str.replace('\"\,','')[::-1]
dat['site_url']=site_url

siteUrl_extract = '(siteUrl":"\w{1,5}\:\//\w{1,3}\.\w{1,13}\.\w{1,2}?\"\,)'   
siteUrl = dat[0].str.extract(siteUrl_extract)
siteUrl = siteUrl.str.replace('siteUrl\"\:\"','')
siteUrl[::-1] = siteUrl.str.replace('\"\,','')[::-1]
dat['siteUrl']=siteUrl


from_url_extract = '(from_url":"\w{1,20}\.?\w{1,2}?\"\,)'   
from_url = dat[0].str.extract(from_url_extract)
from_url= from_url.str.replace('from_url\"\:\"','')
from_url[::-1] = from_url.str.replace('\"\,','')[::-1]
dat['from_url']=from_url



referrerUrl_extract = '(referrerUrl":"\w{1,4}\:\///\w\:\/.{1,14}\/.{1,14}\/.{1,14}\/.{1,250}?\,|referrerUrl":"\w{1,5}\:\//.{1,14}\:.{1,14}\/?\,|referrerUrl":"\w{1,5}\:\//.{1,14}\:.{1,14}\/.{1,14}?\/?.{1,14}?\/?.{1,14}?\,|referrerUrl":"\w{1,5}\:\//.{1,14}\..{1,14}?\/?.{1,100}?\,|referrerUrl":"\w{1,5}\:\//.{1,14}\..{1,14}\.?.{1,250}?\/.{1,250}?\.?.{1,250}?\,|referrerUrl":"\w{1,5}\:\//.{1,14}\..{1,14}\.?.{1,14}?\/.{1,100}\.?.{1,100}?\,|referrerUrl":"\w{1,5}\:\//.{1,14}\..{1,14}\..{1,14}\..{1,14}\:.{1,14}\/.{1,14}\/?.{1,14}?\,|referrerUrl":"\w{1,5}\:\//.{1,14}\..{1,14}\..{1,14}\..{1,14}\:.{1,14}\/.{1,14}\/?.{1,14}?\/?.{1,14}?\,)'     
referrerUrl = dat[0].str.extract(referrerUrl_extract)
referrerUrl = referrerUrl.str.replace('referrerUrl\"\:\"','')
referrerUrl[::-1] = referrerUrl.str.replace('\"\,','')[::-1]
dat['referrerUrl']=referrerUrl

referrHostUrl_extract = '(referrHostUrl":"\w{1,20}\.?\w{1,20}?\.?\w{1,20}\.?\w{1,20}\.?\"\,)'   
referrHostUrl = dat[0].str.extract(referrHostUrl_extract)
referrHostUrl= referrHostUrl.str.replace('referrHostUrl\"\:\"','')
referrHostUrl[::-1] = referrHostUrl.str.replace('\"\,','')[::-1]
dat['referrHostUrl']=referrHostUrl

url_path_extract = '(url_path":"\/?\"\,|url_path":"\/.{1,20}?\/?.{1,100}?\"\,|url_path":"\/.{1,20}?\/?.{1,100}?\/?.{1,100}\"\,)'   
url_path = dat[0].str.extract(url_path_extract)
url_path= url_path.str.replace('url_path\"\:\"','')
url_path[::-1] = url_path.str.replace('\"\,','')[::-1]
dat['url_path']=url_path

referrer_extract = '(referrer":"\w{1,4}\:\///\w\:\/.{1,14}\/.{1,14}\/.{1,14}\/.{1,250}?\,|referrer":"\w{1,5}\:\//.{1,14}\:.{1,14}\/?\,|session_page_url":"\w{1,5}\:\//.{1,14}\:.{1,14}\/.{1,14}?\/?.{1,14}?\/?.{1,14}?\,|referrer":"\w{1,5}\:\//.{1,14}\..{1,14}?\/?.{1,100}?\,|referrer":"\w{1,5}\:\//.{1,14}\..{1,14}\.?.{1,250}?\/.{1,250}?\.?.{1,250}?\,|referrer":"\w{1,5}\:\//.{1,14}\..{1,14}\.?.{1,14}?\/.{1,100}\.?.{1,100}?\,|referrer":"\w{1,5}\:\//.{1,14}\..{1,14}\..{1,14}\..{1,14}\:.{1,14}\/.{1,14}\/?.{1,14}?\,|referrer":"\w{1,5}\:\//.{1,14}\..{1,14}\..{1,14}\..{1,14}\:.{1,14}\/.{1,14}\/?.{1,14}?\/?.{1,14}?\,)'     
referrer = dat[0].str.extract(referrer_extract)
referrer = referrer.str.replace('referrer\"\:\"','')
referrer[::-1] = referrer.str.replace('\"\,','')[::-1]
dat['referrer']=referrer

referrer_host_extract = '(referrer_host":".{1,14}\..{1,14}?\.?.{1,14}?\"\,)'
referrer_host = dat[0].str.extract(referrer_host_extract)
referrer_host = referrer_host.str.replace('referrer_host\"\:\"','')
referrer_host[::-1] = referrer_host.str.replace('\"\,','')[::-1]
dat['referrer_host']=referrer_host

url_extract = '(url":"\w{1,4}\:\///\w\:\/.{1,14}\/.{1,14}\/.{1,14}\/.{1,250}?\,|url":"\w{1,5}\:\//.{1,14}\:.{1,14}\/?\,|url":"\w{1,5}\:\//.{1,14}\:.{1,14}\/.{1,14}?\/?.{1,14}?\/?.{1,14}?\,|url":"\w{1,5}\:\//.{1,14}\..{1,14}?\/?.{1,100}?\,|url":"\w{1,5}\:\//.{1,14}\..{1,14}\.?.{1,250}?\/.{1,250}?\.?.{1,250}?\,|url":"\w{1,5}\:\//.{1,14}\..{1,14}\.?.{1,14}?\/.{1,100}\.?.{1,100}?\,|url":"\w{1,5}\:\//.{1,14}\..{1,14}\..{1,14}\..{1,14}\:.{1,14}\/.{1,14}\/?.{1,14}?\,|url":"\w{1,5}\:\//.{1,14}\..{1,14}\..{1,14}\..{1,14}\:.{1,14}\/.{1,14}\/?.{1,14}?\/?.{1,14}?\,)'     
url = dat[0].str.extract(url_extract)
url = url.str.replace('url\"\:\"','')
url[::-1] = url.str.replace('\"\,','')[::-1]
dat['url']=url



#unnecessary: name, contact, company, email,

# %%
dat.head()
# Out:
#                                                    0  \
# 0  {"distinct_id":"595466e9a8e733434ce08de16e927d...
# 1  {"distinct_id":"9939d3e087bca29c42334d96dccd25...
# 2  {"distinct_id":"9939d3e087bca29c42334d96dccd25...
# 3  {"distinct_id":"9939d3e087bca29c42334d96dccd25...
# 4  {"distinct_id":"9939d3e087bca29c42334d96dccd25...
#
#                                     user_id        event           time  \
# 0  595466e9a8e733434ce08de16e927d985e0b5d48  index_leave  1488791047953
# 1  9939d3e087bca29c42334d96dccd25ca0e06652a          NaN  1490958296645
# 2  9939d3e087bca29c42334d96dccd25ca0e06652a          NaN  1488791050856
# 3  9939d3e087bca29c42334d96dccd25ca0e06652a     btnClick  1488791051772
# 4  9939d3e087bca29c42334d96dccd25ca0e06652a     btnClick  1488791056032
#
#   latest_referrer latest_referrer_host latest_utm_source latest_ch  \
# 0             NaN                  NaN             baidu      demo
# 1             NaN                  NaN               NaN       NaN
# ...

# %%
#url_path_extract = '(url_path":"\/?\"\,)'

# %%
#dat.head(13083)

# %%
url_path_extract = '(url_path":"\/\"\,)'
url_path = dat[0].str.extract(url_path_extract)
url_path = url_path.str.replace('url_path\"\:\"','')
url_path[::-1] = url_path.str.replace('\"\,','')[::-1]
dat['url_path']=url_path
dat.head(324)

# %%
dat.to_csv('C:/Users/Yan/Git/Track2/sensors_dataPreprocessing.csv',encoding = 'utf-8', index = False)

# %%
df = pd.read_csv('C:/Users/Yan/Git/Track2/sensors_dataPreprocessing.csv')

# %%
df.head()
# Out:
#                                                    0  \
# 0  {"distinct_id":"595466e9a8e733434ce08de16e927d...
# 1  {"distinct_id":"9939d3e087bca29c42334d96dccd25...
# 2  {"distinct_id":"9939d3e087bca29c42334d96dccd25...
# 3  {"distinct_id":"9939d3e087bca29c42334d96dccd25...
# 4  {"distinct_id":"9939d3e087bca29c42334d96dccd25...
#
#                                     user_id        event          time  \
# 0  595466e9a8e733434ce08de16e927d985e0b5d48  index_leave  1.488791e+12
# 1  9939d3e087bca29c42334d96dccd25ca0e06652a          NaN  1.490958e+12
# 2  9939d3e087bca29c42334d96dccd25ca0e06652a     pageview  1.488791e+12
# 3  9939d3e087bca29c42334d96dccd25ca0e06652a     btnClick  1.488791e+12
# 4  9939d3e087bca29c42334d96dccd25ca0e06652a     btnClick  1.488791e+12
#
#   latest_referrer latest_referrer_host latest_utm_source latest_ch  \
# 0             NaN                  NaN             baidu      demo
# 1             NaN                  NaN               NaN       NaN
# ...

# %%
df.describe()
# Out:
#                time    os_version  screen_height  screen_width  \
# count  5.104800e+04  33813.000000   44563.000000  44563.000000
# mean   1.489263e+12      7.692198     903.929740   1488.714561
# std    6.585208e+08      2.189952     176.026707    415.879866
# min    1.488791e+12     -1.000000     360.000000    320.000000
# 25%    1.488937e+12      6.100000     768.000000   1366.000000
# 50%    1.489046e+12      6.100000     900.000000   1440.000000
# 75%    1.489143e+12     10.120000    1080.000000   1920.000000
# max    1.490958e+12     10.900000    2560.000000   3840.000000
#
#        browser_version       nocache   requestBtn  pagePosition
# count     44564.000000  5.104800e+04  2962.000000  11334.000000
# mean         38.541209  5.010576e+12     2.232275      1.513676
# std          20.753522  2.885303e+12     1.408734      0.822958
# min          -1.000000  8.076069e+07     1.000000      1.000000
# 25%          10.000000  2.510046e+12     2.000000      1.000000
# ...

# %%
df.shape
# Out:
# (51049, 48)

# %%
df['event'].astype(str).value_counts()
# Out:
# pageview                 22038
# btnClick                  9394
# index_leave               7115
# nan                       6485
# demo_leave                2388
# about_leave                696
# courses_leave              628
# formSubmit                 535
# courses_play_leave         507
# click_send_cellphone       400
# verify_cellphone_code      372
# clickSubmit                353
# page_close                 138
# Name: event, dtype: int64

# %%
help(na)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-76aa48a4e67c> in <module>()
# ----> 1 help(na)
#
# NameError: name 'na' is not defined

# %%
file_json = 'C:/Users/Yan/Git/Track2/sensors_json.json'

# %%
import json
from pandas.io.json import json_normalize

# %%
import json

with open(file_json, 'r') as f:
    table = [json.loads(line) for line in f]
    
d = json_normalize(table)

# %%
d.shape
# Out:
# (51047, 70)

# %%
d.head()
# Out:
#         _nocache                               distinct_id        event  \
# 0  0654392402996  595466e9a8e733434ce08de16e927d985e0b5d48  index_leave
# 1  3040562711955  9939d3e087bca29c42334d96dccd25ca0e06652a          NaN
# 2  9587552771961  9939d3e087bca29c42334d96dccd25ca0e06652a    $pageview
# 3  0652937076129  9939d3e087bca29c42334d96dccd25ca0e06652a     btnClick
# 4  8207407748558  9939d3e087bca29c42334d96dccd25ca0e06652a     btnClick
#
#   jssdk_error lib.$lib lib.$lib_method lib.$lib_version properties.$browser  \
# 0         NaN       js            code           1.6.20              chrome
# 1         NaN       js            code           1.6.20                 NaN
# 2         NaN       js            code           1.6.20              chrome
# 3         NaN       js            code           1.6.20              chrome
# 4         NaN       js            code           1.6.20              chrome
#
#   properties.$browser_version properties.$first_browser_language  \
# ...
